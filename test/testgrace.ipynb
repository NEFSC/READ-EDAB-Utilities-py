# %%
import xesmf
print("Done")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/envs/satprocessing/lib/python3.13/site-packages/xesmf/util.py:8
#       7 try:
# ----> 8     import esmpy as ESMF
#       9 except ImportError:
#
# ModuleNotFoundError: No module named 'esmpy'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import xesmf
#       2 print("Done")
#
# File ~/miniconda3/envs/satprocessing/lib/python3.13/site-packages/xesmf/__init__.py:3
#       1 # flake8: noqa
# ----> 3 from . import data, util
#       4 from .frontend import Regridder, SpatialAverager
#       6 try:
#
# File ~/miniconda3/envs/satprocessing/lib/python3.13/site-packages/xesmf/util.py:10
#       8     import esmpy as ESMF
#       9 except ImportError:
# ---> 10     import ESMF
# ...
